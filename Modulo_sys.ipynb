# %%
import sys

# nombre del modulo
print(sys.argv[0])

# numero de argumentos recibidos
print(len(sys.argv))

# argumentos recibidos
print(sys.argv)

# ruta del sistema operativo donde se encuentra el intérprete de Python
print(sys.prefix)

# version de Python
print(sys.version)

# la ruta de mddulos de Python
print(sys.path)

# nombre del sistema operativo
print(sys.platform)

# lista de mddulos cargados
print(sys.modules )

# Lista de excepciones no manejadas
print(sys.exc_info())

# estado de salida del programa
#print(sys.exit())
# Out:
# /home/carlosa/.local/share/virtualenvs/Notas-Py-Automatizacion-osYMNczG/lib/python3.11/site-packages/ipykernel_launcher.py
# 11
# ['/home/carlosa/.local/share/virtualenvs/Notas-Py-Automatizacion-osYMNczG/lib/python3.11/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9003', '--control=9001', '--hb=9000', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"19fe189e-9f24-4177-8cd6-0d3c31f746a7"', '--shell=9002', '--transport="tcp"', '--iopub=9004', '--f=/home/carlosa/.local/share/jupyter/runtime/kernel-v2-111798IjfdSszj41t.json']
# /home/carlosa/.local/share/virtualenvs/Notas-Py-Automatizacion-osYMNczG
# 3.11.3 (main, Jun  5 2023, 09:32:32) [GCC 13.1.1 20230429]
# ['/run/media/carlosa/Disco/Document_Code/Python/Notas-Py-Automatizacion', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/home/carlosa/.local/share/virtualenvs/Notas-Py-Automatizacion-osYMNczG/lib/python3.11/site-packages']
# linux
# {'sys': <module 'sys' (built-in)>, 'builtins': <module 'builtins' (built-in)>, '_frozen_importlib': <module '_frozen_importlib' (frozen)>, '_imp': <module '_imp' (built-in)>, '_thread': <module '_thread' (built-in)>, '_warnings': <module '_warnings' (built-in)>, '_weakref': <module '_weakref' (built-in)>, '_io': <module '_io' (built-in)>, 'marshal': <module 'marshal' (built-in)>, 'posix': <module 'posix' (built-in)>, '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>, 'time': <module 'time' (built-in)>, 'zipimport': <module 'zipimport' (frozen)>, '_codecs': <module '_codecs' (built-in)>, 'codecs': <module 'codecs' (frozen)>, 'encodings.aliases': <module 'encodings.aliases' from '/usr/lib/python3.11/encodings/aliases.py'>, 'encodings': <module 'encodings' from '/usr/lib/python3.11/encodings/__init__.py'>, 'encodings.utf_8': <module 'encodings.utf_8' from '/usr/lib/python3.11/encodings/utf_8.py'>, '_signal': <module '_signal' (built-in)>, '_abc': <module '_abc' (built-in)>, 'abc': <module 'abc' (frozen)>, 'io': <module 'io' (frozen)>, '__main__': <module '__main__'>, '_stat': <module '_stat' (built-in)>, 'stat': <module 'stat' (frozen)>, '_collections_abc': <module '_collections_abc' (frozen)>, 'genericpath': <module 'genericpath' (frozen)>, 'posixpath': <module 'posixpath' (frozen)>, 'os.path': <module 'posixpath' (frozen)>, 'os': <module 'os' (frozen)>, '_sitebuiltins': <module '_sitebuiltins' (frozen)>, '__future__': <module '__future__' from '/usr/lib/python3.11/__future__.py'>, 'itertools': <module 'itertools' (built-in)>, 'keyword': <module 'keyword' from '/usr/lib/python3.11/keyword.py'>, '_operator': <module '_operator' (built-in)>, 'operator': <module 'operator' from '/usr/lib/python3.11/operator.py'>, 'reprlib': <module 'reprlib' from '/usr/lib/python3.11/reprlib.py'>, '_collections': <module '_collections' (built-in)>, 'collections': <module 'collections' from '/usr/lib/python3.11/collections/__init__.py'>, 'types': <module 'types' from '/usr/lib/python3.11/types.py'>, '_functools': <module '_functools' (built-in)>, 'functools': <module 'functools' from '/usr/lib/python3.11/functools.py'>, 'contextlib': <module 'contextlib' from '/usr/lib/python3.11/contextlib.py'>, '_virtualenv': <module '_virtualenv' from '/home/carlosa/.local/share/virtualenvs/Notas-Py-Automatizacion-osYMNczG/lib/python3.11/site-packages/_virtualenv.py'>, '_distutils_hack': <module '_distutils_hack' from '/home/carlosa/.local/share/virtualenvs/Notas-Py-Automatizacion-osYMNczG/lib/python3.11/site-packages/_distutils_hack/__init__.py'>, 'site': <module 'site' (frozen)>, 'importlib._bootstrap': <module '_frozen_importlib' (frozen)>, 'importlib._bootstrap_external': <module '_frozen_importlib_external' (frozen)>, 'warnings': <module 'warnings' from '/usr/lib/python3.11/warnings.py'>, 'importlib': <module 'importlib' from '/usr/lib/python3.11/importlib/__init__.py'>, 'importlib.machinery': <module 'importlib.machinery' (frozen)>, 'importlib._abc': <module 'importlib._abc' from '/usr/lib/python3.11/importlib/_abc.py'>, 'importlib.util': <module 'importlib.util' (frozen)>, 'runpy': <module 'runpy' (frozen)>, 'enum': <module 'enum' from '/usr/lib/python3.11/enum.py'>, '_sre': <module '_sre' (built-in)>, 're._constants': <module 're._constants' from '/usr/lib/python3.11/re/_constants.py'>, 're._parser': <module 're._parser' from '/usr/lib/python3.11/re/_parser.py'>, 're._casefix': <module 're._casefix' from '/usr/lib/python3.11/re/_casefix.py'>, 're._compiler': <module 're._compiler' from '/usr/lib/python3.11/re/_compiler.py'>, 'copyreg': <module 'copyreg' from '/usr/lib/python3.11/copyreg.py'>, 're': <module 're' from '/usr/lib/python3.11/re/__init__.py'>, 'collections.abc': <module 'collections.abc' from '/usr/lib/python3.11/collections/abc.py'>, '_typing': <module '_typing' from '/usr/lib/python3.11/lib-dynload/_typing.cpython-311-x86_64-linux-gnu.so'>, 'typing.io': <class 'typing.io'>, 'typing.re': <class 'typing.re'>, 'typing' ...
# (None, None, None)

# %% [markdown]
# ![image.png](attachment:image.png)
