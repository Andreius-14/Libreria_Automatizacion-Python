# %%
"""
Tener en cuenta:
    - Iframe e Tablas
    - Descargas Imagenes
    - Extraer Datos Automatizado

    - Url: Interpolacion
    - el Almacenamiento de Los Datos import csv

    ¿Que es requests.get()?
"""

# %% [markdown]
# ### Tarea
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Descargar Imagenes

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### Iframes - Tablas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Extraer Datos de una web - Estilo Tienda

# %% [markdown]
# ![image.png](attachment:image.png)
